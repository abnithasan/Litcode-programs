# %% [markdown]
# <a href="https://colab.research.google.com/github/abnithasan/Litcode-programs/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/abnithasan/Litcode-programs.git
# Out:
# Cloning into 'Litcode-programs'...
# warning: You appear to have cloned an empty repository.

# %%
def FindAutoCount(n):
    d={}
    for i in n:
        if i in d:
            d[i]+=1
        else:
            d[i]=1
    flag=0
    for i in range(len(n)):
        if int(n[i])!=d.get(str(i),0):
            flag=1
            break

    if flag==1:
        print(0)
    else:
        print(len(d)
        )

n=input()
FindAutoCount(n)
# Out:
# 1010
# 0

# %%
n=int(input())
n=bin(n)[2:]
new=""

for i in n:
    if i=="0":
        new+=str(1)
    if i=="1":
        new+=str(0)

decimal=int(new,2)

print(decimal)
# Out:
# 10
# 5
